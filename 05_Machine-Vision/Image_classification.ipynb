# %% [markdown]
# This is a mini project for Machine Vision. Here the goal is an image classifier

# %%
import kagglehub
import shutil
import os
from typing import Tuple, List
from pathlib import Path
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split

# %%
path = kagglehub.dataset_download(
    "hasibalmuzdadid/shoe-vs-sandal-vs-boot-dataset-15k-images"
)
print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/hasibalmuzdadid/shoe-vs-sandal-vs-boot-dataset-15k-images?dataset_version_number=2...
# 100%|██████████| 47.0M/47.0M [00:10<00:00, 4.79MB/s]
# Extracting files...
# Path to dataset files: C:\Users\E1012131\.cache\kagglehub\datasets\hasibalmuzdadid\shoe-vs-sandal-vs-boot-dataset-15k-images\versions\2

# %%
# Setting the directory paths
source_dir = Path(path)
dest_dir = Path("shoe_sandal_boot_dataset")
train_size = 0.7
val_size = 0.15
test_size = 0.15
seed = 42
copy_mode = "copy"
