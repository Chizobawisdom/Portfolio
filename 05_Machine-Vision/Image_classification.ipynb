# %% [markdown]
# This is a mini project for Machine Vision. Here the goal is an image classifier

# %%
import kagglehub
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
path = kagglehub.dataset_download(
    "hasibalmuzdadid/shoe-vs-sandal-vs-boot-dataset-15k-images"
)
print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\E1012131\.cache\kagglehub\datasets\hasibalmuzdadid\shoe-vs-sandal-vs-boot-dataset-15k-images\versions\2

# %%
# preprocess laoded data
